# %%
import bs4; print( 'bs4 ' + bs4.__version__)
from bs4 import BeautifulSoup, SoupStrainer

import nltk; print( 'nltk ' + nltk.__version__)
from nltk import word_tokenize, pos_tag, RegexpParser;
from nltk.tokenize import sent_tokenize

import re; print('re ' + re.__version__)
import requests; print('requests ' + requests.__version__)
# Out:
# bs4 4.6.3
# nltk 3.3
# re 2.2.1
# requests 2.19.1

# %% [markdown]
# # Homework 5 Write Up
#
# All code can be found below
#
# ### 1. Compile a list of static links (permalinks) to individual user movie reviews from one particular
# website. This will be your working dataset for this assignment, as well as for assignments 7 and
# 8, which together will make up your semester project.
#  - It does not matter if you use a crawler or if you manually collect the links, but you will
# need at least 100 movie review links. Note that, as of this writing, the robots.txt file of
# IMDB.com allows the crawling of user reviews.
#  - Each link should be to a web page that has only one user review of only one movie, e.g.,
# the user review permalinks on the IMDB site.
#  - Choose reviews of movies that are all in the same genre, e.g., sci-fi, mystery, romance,
# superhero, etc.
#  - Make sure your collection includes reviews of several movies in your chosen genre and
# that it includes a mix of negative and positive reviews.
#
# >I decided to use various dramas portraied by Tom Hanks. I store the review pages for each of a few of his movies in a variable called `review_home_urls`. Down below I then get all of the reviews and store them in a variable called `all_reviews`. We will have 150 different reviews from these three movies (Green Mile, Forest Gump, and Cast Away, The Terminal, Catch Me If You Can, Road To Perdition)

# %% [markdown]
# ### 2. Extract noun phrase (NP) chunks from your reviews using the following procedure:
#  - In Python, use BeautifulSoup to grab the main review text from each link.
#  - Next run each review text through a tokenizer, and then try to NP-chunk it with a
# shallow parser.
#  - You probably will have too many unknown words, owing to proper names of characters,
# actors, and so on that are not in your working dictionary. Make sure the main names
# that are relevant to the movies in your collection of reviews are added to the working
# lexicon, and then run the NP chunker again.
#
# > I have tokenized and tagged each review and that put them through a shallow parser. The output is pretty good from what I can tell as getting the NPs. I was unable to improve the output.

# %% [markdown]
# ### 3. Output all the chunks in a single list for each review, and submit that output for this assignment.
# Also submit a brief written summary of what you did (describe your selection of genre, your
# source of reviews, how many you collected, and by what means).
#
# > I decided to use dramatic films featuring Tom Hanks mostly because of my adoration for the man as an actor. I used IMDB.com. I manually selected the "main pages" for each movie's review and then iterated over each page to gather links to all the reviews on that page. I have found that each "main page" provide exactly `25 reviews`.

# %% [markdown]
# # Code

# %%
# The home page for various movies' reviews, from which will get the links for individual reviews
review_home_urls = {
    'green_mile': 'https://www.imdb.com/title/tt0120689/reviews?ref_=tt_ql_3',
    'forest_gump': 'https://www.imdb.com/title/tt0109830/reviews?ref_=tt_ov_rt',
    'cast_away': 'https://www.imdb.com/title/tt0162222/reviews?ref_=tt_ov_rt',
    'terminal': 'https://www.imdb.com/title/tt0362227/reviews?ref_=tt_ql_3',
    'catch_me_if_you_can': 'https://www.imdb.com/title/tt0264464/reviews?ref_=tt_ql_3',
    'road_to_perdition': 'https://www.imdb.com/title/tt0257044/reviews?ref_=tt_ql_3',
}

# %%
def get_text_from_url(url):
    return requests.get(url).text
text = get_text_from_url(review_home_urls['green_mile'])

# %%
def get_all_links_from_html(html):
    tags = BeautifulSoup(html, 'html.parser', parse_only=SoupStrainer('a', href=True))
    urls = [str(tag.attrs['href']) for tag in tags]
    return urls
all_links = get_all_links_from_html(text)

# %%
def get_review_urls_from_links(links):
    url_template = 'https://www.imdb.com{}'
    # url_template = 'http://www.gutenberg.org/files/{}/{}-h/{}-h.htm'
    return [url_template.format(link) for link in links]

urls = get_review_urls_from_links(all_links);

# %%
def relevent_link(link):
    if '/review/' in link:
        return True
    return False
def get_relevent_links(links):
    relevent_links = filter(relevent_link, all_links)
    unique_relevent_links = set(relevent_links)
    return list(unique_relevent_links)
relevent_urls = get_relevent_links(urls)
len(relevent_urls)
# Out:
# 25

# %%
def strain_content(name, attrs):
    if name == 'div' and dict(attrs).get('class', None) == 'content':
        return True
    return False
def clean_review_text(text):
    return re.split('\\n\\n\s+\d+ out of \d+', text)[0]
def get_review_from_url(url):
    html = get_text_from_url(url)
    tags = BeautifulSoup(html, 'html.parser', parse_only=SoupStrainer(strain_content))
    review = clean_review_text(tags.text)
    return review

# %%
def get_review_from_site(url):
    reviews = []

    reviews_home_text = get_text_from_url(url)
    all_links = get_all_links_from_html(reviews_home_text)
    relevent_links = get_relevent_links(all_links)

    
    
    
    review_urls = get_review_urls_from_links(relevent_links)
    for url in review_urls:
        reviews.append(get_review_from_url(url))
        # break
    return reviews

# %%
def get_reviews_from_all_sites():
    all_reviews = []
    review_titles = review_home_urls.keys()
    for title in review_titles:
        review_home_url = review_home_urls[title]
        all_reviews = all_reviews + get_review_from_site(review_home_url)
    return all_reviews

# %%
def pos_tagging_for_review(sentence):
    cleaned_review = sentence.lower()
    tokenized_review = word_tokenize(cleaned_review)
    return pos_tag(tokenized_review)
def get_chunking_for_sentence(sentence):
    tagged_sentence = pos_tagging_for_review(sentence)

    grammar = "NP: {<DT>?<JJ>*<NN>}"

    cp = nltk.RegexpParser(grammar)
    result = cp.parse(tagged_sentence)
    return result

def get_chunking_for_review(review):
    sentences = sent_tokenize(review)
    result = [get_chunking_for_sentence(sentence) for sentence in sentences]
    return result

#get_chunking_for_review(all_reviews[0])

# %%
def get_chunking_for_reviews(reviews):
    return [get_chunking_for_review(review) for review in reviews]

# %%
def get_noun_phrases_for_review(review):
    main_trees = get_chunking_for_review(review)
    subtrees = []
    for main_tree in main_trees:
        for subtree in main_tree.subtrees():
            if subtree.label() == 'NP':
                subtrees.append(subtree)
    return subtrees[1:]

# %%
def get_noun_phrases_for_reviews(reviews):
    return [get_noun_phrases_for_review(review) for review in reviews]

# %% [markdown]
# # Question 1

# %%
all_reviews = get_reviews_from_all_sites()

# %%
print(len(all_reviews))
# Out:
# 150

# %% [markdown]
# # Question 2

# %%
noun_phrases_reviews = get_noun_phrases_for_reviews(all_reviews)

# %%
for noun_phrases in noun_phrases_reviews[0:6]:
    for i in range(2):
        print(noun_phrases[i])
    print()
# Out:
# (NP another/DT movie/NN)
# (NP work/NN)
#
# (NP all/DT manner/NN)
# (NP a/DT crime/NN)
#
# (NP ****starring/NN)
# (NP david/JJ morse/NN)
#
# (NP the/DT performance/NN)
# (NP career/NN)
#
# (NP this/DT picture/NN)
# (NP i/NN)
#
# (NP a/DT masterwork/NN)
# (NP film/NN)

# %% [markdown]
# # Question 3

# %%
noun_phrases_reviews
# Out:
# [[Tree('NP', [('another', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('work', 'NN')]),
#   Tree('NP', [('frank', 'JJ'), ('darabont', 'NN')]),
#   Tree('NP', [('prison', 'NN')]),
#   Tree('NP', [('dramas', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('shawshank', 'NN')]),
#   Tree('NP', [('redemption', 'NN')]),
#   Tree('NP', [('real', 'JJ'), ('class', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('clarke', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('performance', 'NN')]),
#   Tree('NP', [('career', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('edge', 'NN')]),
#   Tree('NP', [('seat', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('strong', 'JJ'), ('support', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('talented', 'JJ'), ('ensemble', 'JJ'), ('cast.darabont', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('screenwriter', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('solid', 'JJ'), ('conclusion', 'NN')])],
#  [Tree('NP', [('all', 'DT'), ('manner', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('crime', 'NN')]),
#   Tree('NP', [('stay', 'NN')]),
#   Tree('NP', [('history', 'NN')]),
#   Tree('NP', [('life', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('case', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('realization', 'NN')]),
#   Tree('NP', [('nothing', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('new', 'JJ'), ('prisoner', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('natural', 'JJ'), ('empath', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('prolific', 'JJ'), ('american', 'JJ'), ('horror', 'NN')]),
#   Tree('NP', [('writer', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('unusual', 'JJ'), ('story', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('louisanna', 'NN')]),
#   Tree('NP', [('prison', 'NN')]),
#   Tree('NP', [('joe', 'NN')]),
#   Tree('NP', [('coffee', 'NN')]),
#   Tree('NP', [('enormous', 'JJ'), ('black', 'JJ'), ('man', 'NN')]),
#   Tree('NP', [('murder', 'NN')]),
#   Tree('NP', [('electrocution', 'NN')]),
#   Tree('NP', [('greer', 'NN')]),
#   Tree('NP', [('paul', 'JJ'), ('edgecomb', 'NN')]),
#   Tree('NP', [('prison', 'NN')]),
#   Tree('NP', [('guard', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('state', 'NN')]),
#   Tree('NP', [('prison', 'NN')]),
#   Tree('NP', [("'death", 'JJ'), ('row', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('mr.', 'JJ'), ('coffee', 'NN')]),
#   Tree('NP', [('arrival', 'NN')]),
#   Tree('NP', [('stay', 'NN')]),
#   Tree('NP', [('brutus', 'NN')]),
#   Tree('NP', [('howell', 'NN')]),
#   Tree('NP', [('david', 'JJ'), ('morse', 'NN')]),
#   Tree('NP', [('dean', 'JJ'), ('stanton', 'NN')]),
#   Tree('NP', [('barry', 'JJ'), ('pepper', 'NN')]),
#   Tree('NP', [('harry', 'JJ'), ('terwilliger', 'NN')]),
#   Tree('NP', [('jeffery', 'NN')]),
#   Tree('NP', [('demunn', 'NN')]),
#   Tree('NP', [('particular', 'JJ'), ('sadistic', 'JJ'), ('guard', 'NN')]),
#   Tree('NP', [('percy', 'NN')]),
#   Tree('NP', [('wetmore', 'NN')]),
#   Tree('NP', [('doug', 'JJ'), ('hutchison', 'NN')]),
#   Tree('NP', [('discovery', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('man', 'NN')]),
#   Tree('NP', [('unusual', 'JJ'), ('healing', 'NN')]),
#   Tree('NP', [('innocence', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('steven', 'JJ'), ('king', 'NN')]),
#   Tree('NP', [('application', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('silver', 'NN')]),
#   Tree('NP', [('screen', 'NN')]),
#   Tree('NP', [('adaptation', 'NN')]),
#   Tree('NP', [('duncan', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('superb', 'JJ'), ('ability', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('audience', 'NN')]),
#   Tree('NP', [('true', 'JJ'), ('purpose', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('sadistic', 'JJ'), ('behavior', 'NN')]),
#   Tree('NP', [('hutchison', 'NN')]),
#   Tree('NP', [('ultimate', 'JJ'), ('reward', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('genuine', 'JJ'), ('sympathetic', 'JJ'), ('awe', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('classic', 'JJ'), ('status', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('great', 'JJ'), ('film', 'NN')]),
#   Tree('NP', [('true', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('****', 'NN')])],
#  [Tree('NP', [('****starring', 'NN')]),
#   Tree('NP', [('david', 'JJ'), ('morse', 'NN')]),
#   Tree('NP', [('clarke', 'NN')]),
#   Tree('NP', [('bonnie', 'JJ'), ('hunt', 'NN')]),
#   Tree('NP', [('michael', 'JJ'), ('jeter', 'NN')]),
#   Tree('NP', [('doug', 'NN')]),
#   Tree('NP', [('hutchison', 'NN')]),
#   Tree('NP', [('gary', 'JJ'), ('sinise', 'NN')]),
#   Tree('NP', [('frank', 'JJ'), ('darabont', 'NN')]),
#   Tree('NP', [('time', 'NN')]),
#   Tree('NP', [('r', 'NN')]),
#   Tree('NP', [('violence', 'NN')]),
#   Tree('NP', [('language', 'NN')]),
#   Tree('NP', [('some', 'DT'), ('sexuality', 'NN')]),
#   Tree('NP', [('blake', 'NN')]),
#   Tree('NP', [('french', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('opinion', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('death', 'NN')]),
#   Tree('NP', [('penalty', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('novel', 'NN')]),
#   Tree('NP', [('stephen', 'NN')]),
#   Tree('NP', [('king', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('variety', 'NN')]),
#   Tree('NP', [('audience', 'NN')]),
#   Tree('NP', [('subject', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('handful', 'NN')]),
#   Tree('NP', [('such', 'JJ'), ('power', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('year', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('unique', 'NN')]),
#   Tree('NP', [('hour', 'NN')]),
#   Tree('NP', [('experience', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('personal', 'JJ'), ('narrative', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('actual', 'JJ'), ('plot', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('interesting', 'JJ'), ('perspective', 'NN')]),
#   Tree('NP', [('place', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('man', 'NN')]),
#   Tree('NP', [('age', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('edgecomb', 'NN')]),
#   Tree('NP', [('home', 'NN')]),
#   Tree('NP', [('friend', 'NN')]),
#   Tree('NP', [('elaine', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('very', 'JJ'), ('emotional', 'JJ'), ('day', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('elaine', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('historical', 'JJ'), ('year', 'NN')]),
#   Tree('NP', [('story.he', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('particular', 'JJ'), ('year', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('setting', 'NN')]),
#   Tree('NP', [('prison', 'NN')]),
#   Tree('NP', [('hall', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('kind', 'NN')]),
#   Tree('NP', [('prison', 'NN')]),
#   Tree('NP', [('guard', 'NN')]),
#   Tree('NP', [('death', 'NN')]),
#   Tree('NP', [('row', 'NN')]),
#   Tree('NP', [('charge', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('year', 'NN')]),
#   Tree('NP', [('life', 'NN')]),
#   Tree('NP', [('painful', 'JJ'), ('urinary', 'JJ'), ('infection', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('prisoner', 'NN')]),
#   Tree('NP', [('john', 'NN')]),
#   Tree('NP', [('coffey', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('man', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('electric', 'JJ'), ('chair', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('rape', 'NN')]),
#   Tree('NP', [('murder', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('man', 'NN')]),
#   Tree('NP', [('anyone', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('size', 'NN')]),
#   Tree('NP', [('caring', 'NN')]),
#   Tree('NP', [('place', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('thought', 'NN')]),
#   Tree('NP', [('coffey', 'NN')]),
#   Tree('NP', [('god', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('called', 'JJ'), ('criminal', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('electric', 'JJ'), ('chair', 'NN')]),
#   Tree('NP', [('these', 'DT'), ('capital', 'NN')]),
#   Tree('NP', [('punishment', 'NN')]),
#   Tree('NP', [('much', 'JJ'), ('power', 'NN')]),
#   Tree('NP', [('significance', 'NN')]),
#   Tree('NP', [('material', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('history', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('anti', 'JJ'), ('death', 'NN')]),
#   Tree('NP', [('penalty', 'NN')]),
#   Tree('NP', [('sadistic', 'JJ'), ('world', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('prisoner', 'NN')]),
#   Tree('NP', [('point', 'NN')]),
#   Tree('NP', [('view', 'NN')]),
#   Tree('NP', [('opinion', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('death', 'NN')]),
#   Tree('NP', [('penalty', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('stand', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('issue', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('john', 'NN')]),
#   Tree('NP', [('coffey', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('platform', 'NN')]),
#   Tree('NP', [('religion', 'NN')]),
#   Tree('NP', [('coffey', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('gift', 'NN')]),
#   Tree('NP', [('god', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('character', 'NN')]),
#   Tree('NP', [('dialogue', 'NN')]),
#   Tree('NP', [('religion', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('theme', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('message', 'NN')]),
#   Tree('NP', [('plot', 'NN')]),
#   Tree('NP', [('point', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('imagination', 'NN')]),
#   Tree('NP', [('participation', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('many', 'JJ'), ('vivid', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('everyone', 'NN')]),
#   Tree('NP', [('credit', 'NN')]),
#   Tree('NP', [('review', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('jeter', 'NN')]),
#   Tree('NP', [('gary', 'JJ'), ('sinise', 'NN')]),
#   Tree('NP', [('doug', 'NN')]),
#   Tree('NP', [('hutchison', 'NN')]),
#   Tree('NP', [('bonnie', 'NN')]),
#   Tree('NP', [('hunt', 'NN')]),
#   Tree('NP', [('david', 'JJ'), ('morse', 'NN')]),
#   Tree('NP', [('strength', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('academy', 'NN')]),
#   Tree('NP', [('award', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('clarke', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('golden', 'JJ'), ('globe', 'NN')]),
#   Tree('NP', [('nomination', 'NN')]),
#   Tree('NP', [('role', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('leading', 'JJ'), ('role', 'NN')]),
#   Tree('NP', [('kevin', 'JJ'), ('spacey', 'NN')]),
#   Tree('NP', [('american', 'JJ'), ('beauty', 'NN')]),
#   Tree('NP', [('performance', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('message', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('justice', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('penetrating', 'JJ'), ('dramas', 'NN')]),
#   Tree('NP', [('mind', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('role', 'NN')])],
#  [Tree('NP', [('the', 'DT'), ('performance', 'NN')]),
#   Tree('NP', [('career', 'NN')]),
#   Tree('NP', [('emotion', 'NN')]),
#   Tree('NP', [('depth', 'NN')]),
#   Tree('NP', [('part', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('only', 'JJ'), ('actor', 'NN')]),
#   Tree('NP', [('character', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('vulnerable', 'JJ'), ('pussycat', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('marvel', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('cast', 'NN')]),
#   Tree('NP', [('performance', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('long', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('side', 'NN')]),
#   Tree('NP', [('david', 'JJ'), ('morse', 'NN')]),
#   Tree('NP', [('own', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('hope', 'NN')]),
#   Tree('NP', [('friendship', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('shawshank', 'NN')]),
#   Tree('NP', [('redemption', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('miracle', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('man', 'NN')])],
#  [Tree('NP', [('this', 'DT'), ('picture', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('october', 'NN')]),
#   Tree('NP', [('good.the', 'JJ'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('wonderful', 'JJ'), ('cast', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('shawshank', 'JJ'), ('redemption', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('good', 'JJ'), ('stephen', 'NN')]),
#   Tree('NP', [('king', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('shawshank', 'NN')]),
#   Tree('NP', [('every', 'DT'), ('minute', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('dvd', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')])],
#  [Tree('NP', [('a', 'DT'), ('masterwork', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('art', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('depth', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('cast', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('clear', 'JJ'), ('sense', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('production', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('everything', 'NN')]),
#   Tree('NP', [('craft', 'NN')]),
#   Tree('NP', [('watch', 'NN')]),
#   Tree('NP', [('expression', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('great', 'JJ'), ('power', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('cast', 'NN')]),
#   Tree('NP', [('silence', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('opening', 'NN')]),
#   Tree('NP', [('sequence', 'NN')]),
#   Tree('NP', [('john', 'NN')]),
#   Tree('NP', [('coffey', 'NN')]),
#   Tree('NP', [('emotion', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('unique', 'NN')]),
#   Tree('NP', [('character.the', 'NN')]),
#   Tree('NP', [('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('joy', 'NN')]),
#   Tree('NP', [('laughter', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('theater', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('night', 'NN')]),
#   Tree('NP', [('tears.bravo', 'NN')])],
#  [Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('amazing', 'JJ'), ('degree', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('feeling', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('telling', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('casting', 'NN')]),
#   Tree('NP', [('portrayal', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('steven', 'JJ'), ('king', 'NN')]),
#   Tree('NP', [('novel', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('theater', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('mass', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('end', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('steven', 'JJ'), ('king', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('plan', 'NN')]),
#   Tree('NP', [('video', 'NN')]),
#   Tree('NP', [('collection', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('letter', 'NN')]),
#   Tree('NP', [('box', 'NN')]),
#   Tree('NP', [('version', 'NN')])],
#  [Tree('NP', [('a', 'DT'), ('real', 'JJ'), ('gem', 'NN')]),
#   Tree('NP', [('fault', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('role', 'NN')]),
#   Tree('NP', [('humor', 'NN')]),
#   Tree('NP', [('paul', 'JJ'), ('edgecomb', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('right', 'JJ'), ('flavor', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('single', 'JJ'), ('weak', 'JJ'), ('cast', 'NN')]),
#   Tree('NP', [('member', 'NN')]),
#   Tree('NP', [('jeter', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('oscar', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('clark', 'NN')]),
#   Tree('NP', [('duncan', 'JJ'), ('put', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('right', 'JJ'), ('shading', 'NN')]),
#   Tree('NP', [('huge', 'JJ'), ('character', 'NN')]),
#   Tree('NP', [('perfect', 'JJ'), ('period', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('whole', 'JJ'), ('production', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('extraordinary', 'JJ'), ('story', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('realm', 'NN')]),
#   Tree('NP', [('study', 'NN')]),
#   Tree('NP', [('human', 'JJ'), ('injustice', 'NN')]),
#   Tree('NP', [('charity', 'NN')])],
#  [Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('whole', 'JJ'), ('box', 'NN')]),
#   Tree('NP', [('pure', 'NN')]),
#   Tree('NP', [('love', 'NN')]),
#   Tree('NP', [('honesty', 'NN')]),
#   Tree('NP', [('hair', 'NN')]),
#   Tree('NP', [('anything', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('world', 'NN')]),
#   Tree('NP', [('true', 'JJ'), ('human', 'JJ'), ('love', 'NN')]),
#   Tree('NP', [('compassion', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('hope', 'NN')]),
#   Tree('NP', [('humanity', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('destruction', 'NN')]),
#   Tree('NP', [('race', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('world', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('outlook', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('little', 'JJ'), ('bit', 'NN')]),
#   Tree('NP', [('mine.11/10', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('year', 'NN')]),
#   Tree('NP', [('release', 'NN')])],
#  [Tree('NP', [('a', 'DT'), ('number', 'NN')]),
#   Tree('NP', [('unusual', 'JJ'), ('tale', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('faithful', 'JJ'), ('adaption', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('novel', 'NN')]),
#   Tree('NP', [('stephen', 'NN')]),
#   Tree('NP', [('king', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('fiction', 'NN')]),
#   Tree('NP', [('reader', 'NN')]),
#   Tree('NP', [('vision', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('screen', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('horror', 'NN')]),
#   Tree('NP', [('story', 'NN')]),
#   Tree('NP', [('writer', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('id', 'NN')]),
#   Tree('NP', [('any', 'DT'), ('place', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('american', 'JJ'), ('south', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('man', 'NN')]),
#   Tree('NP', [('john', 'JJ'), ('coffey', 'NN')]),
#   Tree('NP', [('himself.the', 'NN')]),
#   Tree('NP', [('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('cell', 'NN')]),
#   Tree('NP', [('block', 'NN')]),
#   Tree('NP', [('housing', 'NN')]),
#   Tree('NP', [('death', 'NN')]),
#   Tree('NP', [('row', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('cell', 'NN')]),
#   Tree('NP', [('block', 'NN')]),
#   Tree('NP', [('docile', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('baby', 'NN')]),
#   Tree('NP', [('lamb', 'NN')]),
#   Tree('NP', [('request', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('night', 'NN')]),
#   Tree('NP', [('light', 'NN')]),
#   Tree('NP', [('burning', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('little', 'JJ'), ('afraid', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('strange', 'JJ'), ('place', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('dark.of', 'NN')]),
#   Tree('NP', [('course', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('typical', 'JJ'), ('white', 'JJ'), ('alabama', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('day', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('cell', 'NN')]),
#   Tree('NP', [('block', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('rest', 'NN')]),
#   Tree('NP', [('someone', 'NN')]),
#   Tree('NP', [('duncan', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('double', 'JJ'), ('rape/murder', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('child.this', 'JJ'), ('modern', 'JJ'), ('day', 'NN')]),
#   Tree('NP', [('parable', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('jesus', 'NN')]),
#   Tree('NP', [('story', 'NN')]),
#   Tree('NP', [('kind', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('earth', 'NN')]),
#   Tree('NP', [('healing', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('religion', 'NN')]),
#   Tree('NP', [('life', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('one', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('guise', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('illiterate', 'JJ'), ('black', 'JJ'), ('alabama', 'NN')]),
#   Tree('NP', [('sharecropper', 'NN')]),
#   Tree('NP', [('jesus', 'NN')]),
#   Tree('NP', [('brethren', 'NN')]),
#   Tree('NP', [('unto', 'JJ'), ('me.somebody', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('duncan', 'NN')]),
#   Tree('NP', [('size', 'NN')]),
#   Tree('NP', [('build', 'NN')]),
#   Tree('NP', [('anything', 'NN')]),
#   Tree('NP', [('john', 'NN')]),
#   Tree('NP', [('coffey', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('moving', 'JJ'), ('performance', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('history', 'NN')]),
#   Tree('NP', [('difficult', 'JJ'), ('role', 'NN')]),
#   Tree('NP', [('meek', 'NN')]),
#   Tree('NP', [('size', 'NN')]),
#   Tree('NP', [('uncle', 'JJ'), ('tom', 'NN')]),
#   Tree('NP', [('fact', 'NN')]),
#   Tree('NP', [('coffey', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('ordinary', 'JJ'), ('human', 'JJ'), ('mind', 'NN')]),
#   Tree('NP', [('academy', 'NN')]),
#   Tree('NP', [('award', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('case', 'NN')]),
#   Tree('NP', [('actor', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('only', 'JJ'), ('question', 'NN')]),
#   Tree('NP', [('actor', 'NN')]),
#   Tree('NP', [('category', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('picture', 'NN')]),
#   Tree('NP', [('sound', 'NN')]),
#   Tree('NP', [('screenplay', 'NN')]),
#   Tree('NP', [('home', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('winner', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('pity', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('christ-like', 'JJ'), ('figure', 'NN')]),
#   Tree('NP', [('some', 'DT'), ('devil', 'JJ'), ('spawn', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('pair', 'NN')]),
#   Tree('NP', [('sam', 'NN')]),
#   Tree('NP', [('rockwell', 'NN')]),
#   Tree('NP', [('another', 'DT'), ('death', 'NN')]),
#   Tree('NP', [('row', 'NN')]),
#   Tree('NP', [('prisoner', 'NN')]),
#   Tree('NP', [('david', 'JJ'), ('hutchison', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('rat', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('prison', 'NN')]),
#   Tree('NP', [('guard', 'NN')]),
#   Tree('NP', [('true', 'JJ'), ('stephen', 'NN')]),
#   Tree('NP', [('tradition', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('cast', 'NN')]),
#   Tree('NP', [('note', 'NN')]),
#   Tree('NP', [('bonnie', 'JJ'), ('hunt', 'NN')]),
#   Tree('NP', [('mrs.', 'NN')]),
#   Tree('NP', [('clarkson', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('warden', 'NN')]),
#   Tree('NP', [('wife', 'NN')]),
#   Tree('NP', [('david', 'JJ'), ('morse', 'NN')]),
#   Tree('NP', [('barry', 'NN')]),
#   Tree('NP', [('pepper', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('block', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('jeter', 'NN')]),
#   Tree('NP', [('another', 'DT'), ('prisoner', 'NN')]),
#   Tree('NP', [('mouse.the', 'NN')]),
#   Tree('NP', [('green', 'NN')]),
#   Tree('NP', [('mile', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('remarkable', 'JJ'), ('allegorical', 'JJ'), ('picture', 'NN')]),
#   Tree('NP', [('easter', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('season', 'NN')])],
#  [Tree('NP', [('the', 'DT'), ('length', 'NN')]),
#   Tree('NP', [('death', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('.i', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('watch', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('whole', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('opinion', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('performance', 'NN')]),
#   Tree('NP', [('career', 'NN')]),
#   Tree('NP', [('emotion', 'NN')]),
#   Tree('NP', [('depth', 'NN')]),
#   Tree('NP', [('part', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('only', 'JJ'), ('actor', 'NN')]),
#   Tree('NP', [('character', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('vulnerable', 'JJ'), ('pussycat', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('marvel', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('cast', 'NN')]),
#   Tree('NP', [('performance', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('long', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('side', 'NN')]),
#   Tree('NP', [('david', 'JJ'), ('morse', 'NN')]),
#   Tree('NP', [('own', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('running', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('shawshank', 'JJ'), ('redemption', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('little', 'JJ'), ('miracle', 'NN')])],
#  [Tree('NP', [('this', 'DT'), ('oscar', 'NN')]),
#   Tree('NP', [('tour', 'NN')]),
#   Tree('NP', [('force', 'NN')]),
#   Tree('NP', [('imdb', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('fact', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('squeamish', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('first', 'JJ'), ('date', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('impatient', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('stamina', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('end', 'NN')]),
#   Tree('NP', [('capital', 'JJ'), ('punishment', 'NN')]),
#   Tree('NP', [('evil', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('deeply', 'NN')]),
#   Tree('NP', [('spiritual', 'JJ'), ('tale', 'NN')]),
#   Tree('NP', [('creepy', 'JJ'), ('journey', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('rabbit', 'NN')]),
#   Tree('NP', [('hole', 'NN')]),
#   Tree('NP', [('stephen', 'NN')]),
#   Tree('NP', [('king', 'NN')]),
#   Tree('NP', [('mind', 'NN')]),
#   Tree('NP', [('pick', 'NN')]),
#   Tree('NP', [('either', 'DT'), ('way', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('desert', 'NN')]),
#   Tree('NP', [('island', 'NN')]),
#   Tree('NP', [('list', 'NN')]),
#   Tree('NP', [('shawshank', 'JJ'), ('redemption', 'NN')]),
#   Tree('NP', [('required', 'JJ'), ('watching', 'NN')])],
#  [Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('cry', 'NN')]),
#   Tree('NP', [('i', 'JJ'), ('laugh', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('feeling', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('rate', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('bed', 'NN')]),
#   Tree('NP', [('pillow', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('tightest', 'NN')]),
#   Tree('NP', [('grip', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('impression', 'NN')]),
#   Tree('NP', [('mind', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('long', 'JJ'), ('time', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('shawshank', 'JJ'), ('redemption.fantastic', 'JJ'), ('story', 'NN')]),
#   Tree('NP', [('brilliant', 'JJ'), ('acting', 'NN')]),
#   Tree('NP', [('mind', 'NN')]),
#   Tree('NP', [('boggling', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('unforgettable', 'JJ'), ('drama', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('journey', 'NN')]),
#   Tree('NP', [('next', 'JJ'), ('generation', 'NN')])],
#  [Tree('NP', [('favorite', 'JJ'), ('stephen', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('version', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('emotional', 'JJ'), ('impact', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('book', 'NN')]),
#   Tree('NP', [('screen', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('wonderful', 'JJ'), ('story', 'NN')]),
#   Tree('NP', [('frank', 'JJ'), ('darabont', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('magnificent', 'JJ'), ('job', 'NN')]),
#   Tree('NP', [('king', 'NN')]),
#   Tree('NP', [('shawshank', 'JJ'), ('redemption', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('screen', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('same', 'JJ'), ('high', 'JJ'), ('quality', 'NN')]),
#   Tree('NP', [('work', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('book', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('casting', 'NN')]),
#   Tree('NP', [('every', 'DT'), ('actor', 'NN')]),
#   Tree('NP', [('role', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('excellent', 'JJ'), ('job', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('doug', 'JJ'), ('hutchison', 'NN')]),
#   Tree('NP', [('portrayal', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('detestable', 'JJ'), ('percy', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('mark', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('character', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('book', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('length', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('length', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('way', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('darabont', 'NN')]),
#   Tree('NP', [('much', 'JJ'), ('emotion', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('screen', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('baby', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')])],
#  [Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('novel', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('same', 'JJ'), ('name', 'NN')]),
#   Tree('NP', [('stephen', 'NN')]),
#   Tree('NP', [('king', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('book', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('great', 'JJ'), ('read', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('book', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('year', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('scene', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('book', 'NN')]),
#   Tree('NP', [('plot', 'NN')]),
#   Tree('NP', [('point', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('book', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('way', 'NN')]),
#   Tree('NP', [('detract', 'NN')]),
#   Tree('NP', [('either', 'DT'), ('work', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('john', 'NN')]),
#   Tree('NP', [('coffey', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('edgecomb', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('jeter', 'NN')]),
#   Tree('NP', [('recognition', 'NN')]),
#   Tree('NP', [('eduard', 'JJ'), ('delacroix', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('book', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('favorite', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('book', 'NN')]),
#   Tree('NP', [('hayworth', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('shawshank', 'NN')]),
#   Tree('NP', [('redemption', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('hope', 'NN')]),
#   Tree('NP', [('friendship', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('shawshank', 'NN')]),
#   Tree('NP', [('redemption', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('miracle', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('man', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('shawshank', 'NN')]),
#   Tree('NP', [('redemption', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('great', 'JJ'), ('story', 'NN')]),
#   Tree('NP', [('great', 'JJ'), ('cast', 'NN')]),
#   Tree('NP', [('great', 'JJ'), ('look', 'NN')])],
#  [Tree('NP', [('chair', 'NN')]),
#   Tree('NP', [('another', 'DT'), ('adaptation', 'NN')]),
#   Tree('NP', [('novel', 'NN')]),
#   Tree('NP', [('place', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('death', 'NN')]),
#   Tree('NP', [('row', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('character-driven', 'JJ'), ('fantasy', 'JJ'), ('tale', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('mile', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('arrival', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('giant', 'JJ'), ('man', 'NN')]),
#   Tree('NP', [('john', 'NN')]),
#   Tree('NP', [('coffey', 'NN')]),
#   Tree('NP', [('michael', 'JJ'), ('duncan', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('murder', 'NN')]),
#   Tree('NP', [('single', 'JJ'), ('story', 'NN')]),
#   Tree('NP', [('seamlessly.a', 'JJ'), ('character-driven', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('lot', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('cast', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('poster', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('edgecomb', 'NN')]),
#   Tree('NP', [('senior', 'JJ'), ('prison', 'NN')]),
#   Tree('NP', [('guard', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('mile', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('cast', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('face', 'NN')]),
#   Tree('NP', [('inevitably', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('new', 'JJ'), ('role', 'NN')]),
#   Tree('NP', [('doug', 'NN')]),
#   Tree('NP', [('hutchison', 'NN')]),
#   Tree('NP', [('percy', 'NN')]),
#   Tree('NP', [('wetmore', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('mean', 'NN')]),
#   Tree('NP', [('prison', 'NN')]),
#   Tree('NP', [('guard', 'NN')]),
#   Tree('NP', [('character', 'NN')]),
#   Tree('NP', [('captivating', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('performance', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('duncan.it', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('flaw', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('camerawork', 'NN')]),
#   Tree('NP', [('direction', 'NN')]),
#   Tree('NP', [('flawless', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('considerable', 'JJ'), ('length', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('bit', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('marvellous', 'JJ'), ('cast', 'NN')]),
#   Tree('NP', [('firm', 'JJ'), ('pace', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('attention', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('touching', 'JJ'), ('culmination', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('style', 'NN')]),
#   Tree('NP', [('combination', 'NN')]),
#   Tree('NP', [('simplicity', 'NN')]),
#   Tree('NP', [('depth', 'NN')]),
#   Tree('NP', [('conversation.all', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('touching', 'JJ'), ('drama', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('life', 'NN')]),
#   Tree('NP', [('great', 'JJ'), ('skill', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('year', 'NN')])],
#  [Tree('NP', [('an', 'DT'), ('amazing', 'JJ'), ('actor', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('sensitive', 'JJ'), ('role', 'NN')])],
#  [Tree('NP', [('another', 'DT'), ('masterpiece', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('steven', 'JJ'), ('king', 'NN')]),
#   Tree('NP', [('novel.sheer', 'NN')]),
#   Tree('NP', [('brilliance', 'NN')]),
#   Tree('NP', [('performance', 'NN')]),
#   Tree('NP', [('officer', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('edgecombe', 'NN')]),
#   Tree('NP', [('one.while', 'JJ'), ('tom', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('credit', 'NN')]),
#   Tree('NP', [('magnificent', 'NN')]),
#   Tree('NP', [('portrayal', 'NN')]),
#   Tree('NP', [('john', 'JJ'), ('coffey-a', 'NN')]),
#   Tree('NP', [('foot', 'NN')]),
#   Tree('NP', [('tall', 'NN')]),
#   Tree('NP', [('giant', 'NN')]),
#   Tree('NP', [('murderer.he', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('killing', 'NN')]),
#   Tree('NP', [('time', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('gentle', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('murder.the', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('characters.the', 'JJ'), ('deep', 'JJ'), ('emotional', 'JJ'), ('drama', 'NN')]),
#   Tree('NP', [('darabont', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('source', 'NN')]),
#   Tree('NP', [('material', 'NN')]),
#   Tree('NP', [('shawshank', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('value', 'NN')]),
#   Tree('NP', [('human', 'JJ'), ('life', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('innocent', 'JJ'), ('man', 'NN')]),
#   Tree('NP', [('prison', 'NN')]),
#   Tree('NP', [('andy', 'JJ'), ('john', 'NN')]),
#   Tree('NP', [('god.he', 'NN')]),
#   Tree('NP', [('forth', 'NN')]),
#   Tree('NP', [('sympathy', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('end', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('audience', 'NN')]),
#   Tree('NP', [('previous', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('mr', 'NN')]),
#   Tree('NP', [('darabont', 'NN')]),
#   Tree('NP', [('another', 'DT'), ('fantastic', 'JJ'), ('film', 'NN')]),
#   Tree('NP', [('sure', 'NN')]),
#   Tree('NP', [('heart', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('while.steven', 'JJ'), ('king', 'NN')])],
#  [Tree('NP', [('director', 'NN')]),
#   Tree('NP', [('frank', 'JJ'), ('darabont', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('overall', 'JJ'), ('wonderful', 'JJ'), ('film', 'NN')]),
#   Tree('NP', [('heart', 'NN')]),
#   Tree('NP', [('sad.the', 'NN')]),
#   Tree('NP', [('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('prison', 'NN')]),
#   Tree('NP', [('guard', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('year', 'NN')]),
#   Tree('NP', [('john', 'NN')]),
#   Tree('NP', [('coffey', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('death', 'NN')]),
#   Tree('NP', [('row', 'NN')]),
#   Tree('NP', [('inmate', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('coffey', 'NN')]),
#   Tree('NP', [('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('heart', 'NN')]),
#   Tree('NP', [('wonderful', 'JJ'), ('story', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('john', 'NN')]),
#   Tree('NP', [('fantastic', 'JJ'), ('performances.aside', 'NN')]),
#   Tree('NP', [('duncan', 'NN')]),
#   Tree('NP', [('marvelous', 'JJ'), ('coffey', 'NN')]),
#   Tree('NP', [('performance', 'NN')]),
#   Tree('NP', [('doug', 'JJ'), ('hutchinson', 'NN')]),
#   Tree('NP', [('percy', 'NN')]),
#   Tree('NP', [('hatable', 'JJ'), ('character', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('bad', 'JJ'), ('guy', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('guy', 'NN')]),
#   Tree('NP', [('percy', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('arrogant', 'JJ'), ('doushbag', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('actual', 'JJ'), ('villain', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('sad', 'JJ'), ('note', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('shawshank', 'JJ'), ('redemption', 'NN')]),
#   Tree('NP', [('sue', 'NN')])],
#  [Tree('NP', [('an', 'DT'), ('elite', 'JJ'), ('group', 'NN')]),
#   Tree('NP', [('honor', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('climax', 'NN')]),
#   Tree('NP', [('possibility', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('human', 'JJ'), ('mind', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('kind', 'NN')]),
#   Tree('NP', [('it.i', 'JJ'), ('love', 'NN')]),
#   Tree('NP', [('drama', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('length', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('lot', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('interest.one', 'NN')]),
#   Tree('NP', [('all', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('doubt', 'NN')])],
#  [Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('anyone', 'NN')]),
#   Tree('NP', [('life', 'NN')]),
#   Tree('NP', [('experience', 'NN')]),
#   Tree('NP', [('everything', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('someone', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('fiancée', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('electrifying', 'JJ'), ('experience', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('venture', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('all', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')])],
#  [Tree('NP', [('a', 'DT'), ('wonderful', 'JJ'), ('film', 'NN')]),
#   Tree('NP', [('imo', 'NN')]),
#   Tree('NP', [('every', 'DT'), ('human', 'JJ'), ('level', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('brilliant', 'JJ'), ('storyline', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('faithful', 'JJ'), ('screenplay', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('inspired', 'JJ'), ('choice', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('clarke', 'NN')]),
#   Tree('NP', [('fact', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('cast', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('mouse', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('simple', 'JJ'), ('man', 'NN')]),
#   Tree('NP', [('type', 'NN')]),
#   Tree('NP', [('crime', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('real', 'JJ'), ('recourse', 'NN')]),
#   Tree('NP', [('justice', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('subplot', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('main', 'JJ'), ('focus', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('john', 'JJ'), ('coffey', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('gift', 'NN')]),
#   Tree('NP', [('god', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('pain', 'NN')]),
#   Tree('NP', [('watchingboth', 'JJ'), ('bitterbuck', 'NN')]),
#   Tree('NP', [('delacroix', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('death', 'NN')]),
#   Tree('NP', [('penaltypercy', 'NN')]),
#   Tree('NP', [('offensive', 'JJ'), ('behaviour', 'NN')]),
#   Tree('NP', [('humanity', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('edgecomb', 'NN')]),
#   Tree('NP', [('emotive', 'JJ'), ('actor', 'NN')]),
#   Tree('NP', [('tom', 'NN')]),
#   Tree('NP', [('john', 'NN')]),
#   Tree('NP', [('coffey', 'NN')]),
#   Tree('NP', [('beautiful', 'JJ'), ('film', 'NN')])],
#  [Tree('NP', [('an', 'DT'), ('experience', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('own', 'JJ'), ('existence', 'NN')]),
#   Tree('NP', [('corner', 'NN')]),
#   Tree('NP', [('own', 'JJ'), ('life', 'NN')]),
#   Tree('NP', [('hope', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('triumph', 'NN')]),
#   Tree('NP', [('sacrifice', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('part', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('theater', 'NN')]),
#   Tree('NP', [('feeling', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('little', 'JJ'), ('cursed.i', 'NN')]),
#   Tree('NP', [('think', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('edgecomb', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('same', 'JJ'), ('way.tom', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('epitome', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('hollywood', 'NN')]),
#   Tree('NP', [('legend', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('guy', 'NN')]),
#   Tree('NP', [('way', 'NN')]),
#   Tree('NP', [('turner', 'NN')]),
#   Tree('NP', [('hooch', 'NN')]),
#   Tree('NP', [('bachelor', 'NN')]),
#   Tree('NP', [('party', 'NN')]),
#   Tree('NP', [('everyman', 'NN')]),
#   Tree('NP', [('anyone', 'NN')]),
#   Tree('NP', [('simple', 'JJ'), ('guy', 'NN')]),
#   Tree('NP', [('gump', 'NN')]),
#   Tree('NP', [('private', 'JJ'), ('ryan', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('oscar', 'NN')]),
#   Tree('NP', [('nomination', 'NN')]),
#   Tree('NP', [('arow', 'NN')]),
#   Tree('NP', [('tom', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('back.the', 'NN')]),
#   Tree('NP', [('breakout', 'NN')]),
#   Tree('NP', [('performance', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('clark', 'NN')]),
#   Tree('NP', [('sixth', 'JJ'), ('sense', 'NN')]),
#   Tree('NP', [('haley', 'NN')]),
#   Tree('NP', [('joel', 'NN')]),
#   Tree('NP', [('osment', 'NN')]),
#   Tree('NP', [('actor', 'NN')]),
#   Tree('NP', [('vote', 'NN')]),
#   Tree('NP', [('size', 'NN')]),
#   Tree('NP', [('mr.', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('limit', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('role', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('child-like', 'JJ'), ('behemoth', 'NN')]),
#   Tree('NP', [('healing', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('screen', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('performance', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('world.the', 'NN')]),
#   Tree('NP', [('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('cell', 'JJ'), ('block', 'NN')]),
#   Tree('NP', [('e', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('louisiana', 'JJ'), ('state', 'NN')]),
#   Tree('NP', [('prison', 'NN')]),
#   Tree('NP', [('death', 'NN')]),
#   Tree('NP', [('row', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('edgecomb', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('wing', 'NN')]),
#   Tree('NP', [('compassion', 'NN')]),
#   Tree('NP', [('different', 'JJ'), ('approach', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('legendary', 'JJ'), ('cruelty', 'NN')]),
#   Tree('NP', [('all', 'DT'), ('share', 'NN')]),
#   Tree('NP', [('philosophy', 'NN')]),
#   Tree('NP', [('devastating', 'JJ'), ('punishment', 'NN')]),
#   Tree('NP', [('stay', 'NN')]),
#   Tree('NP', [('percy', 'NN')]),
#   Tree('NP', [('wetmore', 'NN')]),
#   Tree('NP', [('doug', 'JJ'), ('hutchinson', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('governor', 'NN')]),
#   Tree('NP', [('anyone', 'NN')]),
#   Tree('NP', [('job', 'NN')]),
#   Tree('NP', [('percy', 'NN')]),
#   Tree('NP', [('everything', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('brave', 'JJ'), ('mouse', 'NN')]),
#   Tree('NP', [('michael', 'JJ'), ('jeter', 'NN')]),
#   Tree('NP', [('another', 'DT'), ('new', 'JJ'), ('inmate', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('man', 'NN')]),
#   Tree('NP', [('wild', 'JJ'), ('bill', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('percy', 'NN')]),
#   Tree('NP', [('equal.so', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('common', 'JJ'), ('thread', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('messianic', 'JJ'), ('character', 'NN')]),
#   Tree('NP', [('death', 'NN')]),
#   Tree('NP', [('row', 'NN')]),
#   Tree('NP', [('role', 'NN')]),
#   Tree('NP', [('redemption', 'NN')]),
#   Tree('NP', [('curse', 'NN')]),
#   Tree('NP', [('thing', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('beginning', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('review', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('money', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('box', 'NN')]),
#   Tree('NP', [('office', 'NN')]),
#   Tree('NP', [('john', 'NN')]),
#   Tree('NP', [('coffey', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('common', 'JJ'), ('ground', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('world.if', 'NN')]),
#   Tree('NP', [('john', 'NN')]),
#   Tree('NP', [('coffey', 'NN')]),
#   Tree('NP', [('crime', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('half', 'NN')]),
#   Tree('NP', [('half', 'NN')]),
#   Tree('NP', [('evil', 'NN')]),
#   Tree('NP', [('bu', 'JJ'), ('t', 'NN')]),
#   Tree('NP', [('goodness', 'NN')]),
#   Tree('NP', [('witness', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('price', 'NN')]),
#   Tree('NP', [('another', 'DT'), ('academy', 'NN')]),
#   Tree('NP', [('award', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('good', 'JJ'), ('film', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('incredible', 'JJ'), ('film.i', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('edgecomb', 'NN')])],
#  [Tree('NP', [('favorite', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('lot', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('feeling', 'NN')]),
# ...
#   Tree('NP', [('considerable', 'JJ'), ('length', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('bit', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('marvellous', 'JJ'), ('cast', 'NN')]),
#   Tree('NP', [('firm', 'JJ'), ('pace', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('attention', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('touching', 'JJ'), ('culmination', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('style', 'NN')]),
#   Tree('NP', [('combination', 'NN')]),
#   Tree('NP', [('simplicity', 'NN')]),
#   Tree('NP', [('depth', 'NN')]),
#   Tree('NP', [('conversation.all', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('touching', 'JJ'), ('drama', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('life', 'NN')]),
#   Tree('NP', [('great', 'JJ'), ('skill', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('year', 'NN')])],
#  [Tree('NP', [('an', 'DT'), ('amazing', 'JJ'), ('actor', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('sensitive', 'JJ'), ('role', 'NN')])],
#  [Tree('NP', [('another', 'DT'), ('masterpiece', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('steven', 'JJ'), ('king', 'NN')]),
#   Tree('NP', [('novel.sheer', 'NN')]),
#   Tree('NP', [('brilliance', 'NN')]),
#   Tree('NP', [('performance', 'NN')]),
#   Tree('NP', [('officer', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('edgecombe', 'NN')]),
#   Tree('NP', [('one.while', 'JJ'), ('tom', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('credit', 'NN')]),
#   Tree('NP', [('magnificent', 'NN')]),
#   Tree('NP', [('portrayal', 'NN')]),
#   Tree('NP', [('john', 'JJ'), ('coffey-a', 'NN')]),
#   Tree('NP', [('foot', 'NN')]),
#   Tree('NP', [('tall', 'NN')]),
#   Tree('NP', [('giant', 'NN')]),
#   Tree('NP', [('murderer.he', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('killing', 'NN')]),
#   Tree('NP', [('time', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('gentle', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('murder.the', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('characters.the', 'JJ'), ('deep', 'JJ'), ('emotional', 'JJ'), ('drama', 'NN')]),
#   Tree('NP', [('darabont', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('source', 'NN')]),
#   Tree('NP', [('material', 'NN')]),
#   Tree('NP', [('shawshank', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('value', 'NN')]),
#   Tree('NP', [('human', 'JJ'), ('life', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('innocent', 'JJ'), ('man', 'NN')]),
#   Tree('NP', [('prison', 'NN')]),
#   Tree('NP', [('andy', 'JJ'), ('john', 'NN')]),
#   Tree('NP', [('god.he', 'NN')]),
#   Tree('NP', [('forth', 'NN')]),
#   Tree('NP', [('sympathy', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('end', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('audience', 'NN')]),
#   Tree('NP', [('previous', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('mr', 'NN')]),
#   Tree('NP', [('darabont', 'NN')]),
#   Tree('NP', [('another', 'DT'), ('fantastic', 'JJ'), ('film', 'NN')]),
#   Tree('NP', [('sure', 'NN')]),
#   Tree('NP', [('heart', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('while.steven', 'JJ'), ('king', 'NN')])],
#  [Tree('NP', [('director', 'NN')]),
#   Tree('NP', [('frank', 'JJ'), ('darabont', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('overall', 'JJ'), ('wonderful', 'JJ'), ('film', 'NN')]),
#   Tree('NP', [('heart', 'NN')]),
#   Tree('NP', [('sad.the', 'NN')]),
#   Tree('NP', [('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('prison', 'NN')]),
#   Tree('NP', [('guard', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('year', 'NN')]),
#   Tree('NP', [('john', 'NN')]),
#   Tree('NP', [('coffey', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('death', 'NN')]),
#   Tree('NP', [('row', 'NN')]),
#   Tree('NP', [('inmate', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('coffey', 'NN')]),
#   Tree('NP', [('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('heart', 'NN')]),
#   Tree('NP', [('wonderful', 'JJ'), ('story', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('john', 'NN')]),
#   Tree('NP', [('fantastic', 'JJ'), ('performances.aside', 'NN')]),
#   Tree('NP', [('duncan', 'NN')]),
#   Tree('NP', [('marvelous', 'JJ'), ('coffey', 'NN')]),
#   Tree('NP', [('performance', 'NN')]),
#   Tree('NP', [('doug', 'JJ'), ('hutchinson', 'NN')]),
#   Tree('NP', [('percy', 'NN')]),
#   Tree('NP', [('hatable', 'JJ'), ('character', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('bad', 'JJ'), ('guy', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('guy', 'NN')]),
#   Tree('NP', [('percy', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('arrogant', 'JJ'), ('doushbag', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('actual', 'JJ'), ('villain', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('sad', 'JJ'), ('note', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('shawshank', 'JJ'), ('redemption', 'NN')]),
#   Tree('NP', [('sue', 'NN')])],
#  [Tree('NP', [('an', 'DT'), ('elite', 'JJ'), ('group', 'NN')]),
#   Tree('NP', [('honor', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('climax', 'NN')]),
#   Tree('NP', [('possibility', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('human', 'JJ'), ('mind', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('kind', 'NN')]),
#   Tree('NP', [('it.i', 'JJ'), ('love', 'NN')]),
#   Tree('NP', [('drama', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('length', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('lot', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('interest.one', 'NN')]),
#   Tree('NP', [('all', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('doubt', 'NN')])],
#  [Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('anyone', 'NN')]),
#   Tree('NP', [('life', 'NN')]),
#   Tree('NP', [('experience', 'NN')]),
#   Tree('NP', [('everything', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('someone', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('fiancée', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('electrifying', 'JJ'), ('experience', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('venture', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('all', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')])],
#  [Tree('NP', [('a', 'DT'), ('wonderful', 'JJ'), ('film', 'NN')]),
#   Tree('NP', [('imo', 'NN')]),
#   Tree('NP', [('every', 'DT'), ('human', 'JJ'), ('level', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('brilliant', 'JJ'), ('storyline', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('faithful', 'JJ'), ('screenplay', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('inspired', 'JJ'), ('choice', 'NN')]),
#   Tree('NP', [('michael', 'NN')]),
#   Tree('NP', [('clarke', 'NN')]),
#   Tree('NP', [('fact', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('cast', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('mouse', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('story', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('simple', 'JJ'), ('man', 'NN')]),
#   Tree('NP', [('type', 'NN')]),
#   Tree('NP', [('crime', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('time', 'NN')]),
#   Tree('NP', [('no', 'DT'), ('real', 'JJ'), ('recourse', 'NN')]),
#   Tree('NP', [('justice', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('subplot', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('main', 'JJ'), ('focus', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('john', 'JJ'), ('coffey', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('gift', 'NN')]),
#   Tree('NP', [('god', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('pain', 'NN')]),
#   Tree('NP', [('watchingboth', 'JJ'), ('bitterbuck', 'NN')]),
#   Tree('NP', [('delacroix', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('death', 'NN')]),
#   Tree('NP', [('penaltypercy', 'NN')]),
#   Tree('NP', [('offensive', 'JJ'), ('behaviour', 'NN')]),
#   Tree('NP', [('humanity', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('edgecomb', 'NN')]),
#   Tree('NP', [('emotive', 'JJ'), ('actor', 'NN')]),
#   Tree('NP', [('tom', 'NN')]),
#   Tree('NP', [('john', 'NN')]),
#   Tree('NP', [('coffey', 'NN')]),
#   Tree('NP', [('beautiful', 'JJ'), ('film', 'NN')])],
#  [Tree('NP', [('an', 'DT'), ('experience', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('own', 'JJ'), ('existence', 'NN')]),
#   Tree('NP', [('corner', 'NN')]),
#   Tree('NP', [('own', 'JJ'), ('life', 'NN')]),
#   Tree('NP', [('hope', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('triumph', 'NN')]),
#   Tree('NP', [('sacrifice', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('part', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('theater', 'NN')]),
#   Tree('NP', [('feeling', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('little', 'JJ'), ('cursed.i', 'NN')]),
#   Tree('NP', [('think', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('edgecomb', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('same', 'JJ'), ('way.tom', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('epitome', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('hollywood', 'NN')]),
#   Tree('NP', [('legend', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('guy', 'NN')]),
#   Tree('NP', [('way', 'NN')]),
#   Tree('NP', [('turner', 'NN')]),
#   Tree('NP', [('hooch', 'NN')]),
#   Tree('NP', [('bachelor', 'NN')]),
#   Tree('NP', [('party', 'NN')]),
#   Tree('NP', [('everyman', 'NN')]),
#   Tree('NP', [('anyone', 'NN')]),
#   Tree('NP', [('simple', 'JJ'), ('guy', 'NN')]),
#   Tree('NP', [('gump', 'NN')]),
#   Tree('NP', [('private', 'JJ'), ('ryan', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('oscar', 'NN')]),
#   Tree('NP', [('nomination', 'NN')]),
#   Tree('NP', [('arow', 'NN')]),
#   Tree('NP', [('tom', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('back.the', 'NN')]),
#   Tree('NP', [('breakout', 'NN')]),
#   Tree('NP', [('performance', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('clark', 'NN')]),
#   Tree('NP', [('sixth', 'JJ'), ('sense', 'NN')]),
#   Tree('NP', [('haley', 'NN')]),
#   Tree('NP', [('joel', 'NN')]),
#   Tree('NP', [('osment', 'NN')]),
#   Tree('NP', [('actor', 'NN')]),
#   Tree('NP', [('vote', 'NN')]),
#   Tree('NP', [('size', 'NN')]),
#   Tree('NP', [('mr.', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('limit', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('role', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('child-like', 'JJ'), ('behemoth', 'NN')]),
#   Tree('NP', [('healing', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('screen', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('performance', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('world.the', 'NN')]),
#   Tree('NP', [('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('cell', 'JJ'), ('block', 'NN')]),
#   Tree('NP', [('e', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('louisiana', 'JJ'), ('state', 'NN')]),
#   Tree('NP', [('prison', 'NN')]),
#   Tree('NP', [('death', 'NN')]),
#   Tree('NP', [('row', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('edgecomb', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('wing', 'NN')]),
#   Tree('NP', [('compassion', 'NN')]),
#   Tree('NP', [('different', 'JJ'), ('approach', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('legendary', 'JJ'), ('cruelty', 'NN')]),
#   Tree('NP', [('all', 'DT'), ('share', 'NN')]),
#   Tree('NP', [('philosophy', 'NN')]),
#   Tree('NP', [('devastating', 'JJ'), ('punishment', 'NN')]),
#   Tree('NP', [('stay', 'NN')]),
#   Tree('NP', [('percy', 'NN')]),
#   Tree('NP', [('wetmore', 'NN')]),
#   Tree('NP', [('doug', 'JJ'), ('hutchinson', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('governor', 'NN')]),
#   Tree('NP', [('anyone', 'NN')]),
#   Tree('NP', [('job', 'NN')]),
#   Tree('NP', [('percy', 'NN')]),
#   Tree('NP', [('everything', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('brave', 'JJ'), ('mouse', 'NN')]),
#   Tree('NP', [('michael', 'JJ'), ('jeter', 'NN')]),
#   Tree('NP', [('another', 'DT'), ('new', 'JJ'), ('inmate', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('man', 'NN')]),
#   Tree('NP', [('wild', 'JJ'), ('bill', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('percy', 'NN')]),
#   Tree('NP', [('equal.so', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('common', 'JJ'), ('thread', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('messianic', 'JJ'), ('character', 'NN')]),
#   Tree('NP', [('death', 'NN')]),
#   Tree('NP', [('row', 'NN')]),
#   Tree('NP', [('role', 'NN')]),
#   Tree('NP', [('redemption', 'NN')]),
#   Tree('NP', [('curse', 'NN')]),
#   Tree('NP', [('thing', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('beginning', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('review', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('money', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('box', 'NN')]),
#   Tree('NP', [('office', 'NN')]),
#   Tree('NP', [('john', 'NN')]),
#   Tree('NP', [('coffey', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('common', 'JJ'), ('ground', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('world.if', 'NN')]),
#   Tree('NP', [('john', 'NN')]),
#   Tree('NP', [('coffey', 'NN')]),
#   Tree('NP', [('crime', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('film', 'NN')]),
#   Tree('NP', [('half', 'NN')]),
#   Tree('NP', [('half', 'NN')]),
#   Tree('NP', [('evil', 'NN')]),
#   Tree('NP', [('bu', 'JJ'), ('t', 'NN')]),
#   Tree('NP', [('goodness', 'NN')]),
#   Tree('NP', [('witness', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('price', 'NN')]),
#   Tree('NP', [('another', 'DT'), ('academy', 'NN')]),
#   Tree('NP', [('award', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('good', 'JJ'), ('film', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('incredible', 'JJ'), ('film.i', 'NN')]),
#   Tree('NP', [('paul', 'NN')]),
#   Tree('NP', [('edgecomb', 'NN')])],
#  [Tree('NP', [('favorite', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('lot', 'NN')]),
#   Tree('NP', [('that', 'DT'), ('feeling', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('frank', 'JJ'), ('darabont', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('overload', 'NN')]),
#   Tree('NP', [('every', 'DT'), ('character', 'NN')]),
#   Tree('NP', [('something', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('acting', 'NN')]),
#   Tree('NP', [('right', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('anyone', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('whole', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('script', 'NN')]),
#   Tree('NP', [('heartfelt', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('villain', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('green', 'JJ'), ('mile', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('an', 'DT'), ('emotive', 'JJ'), ('story.what', 'NN')])],
#  [Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('run', 'NN')]),
#   Tree('NP', [('time', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('huge', 'JJ'), ('success', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('main', 'JJ'), ('character', 'NN')]),
#   Tree('NP', [('micheal', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('spotlight', 'NN')]),
#   Tree('NP', [('novel', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('same', 'JJ'), ('title', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('tall', 'JJ'), ('i', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('little', 'JJ'), ('gem', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('fan', 'NN')]),
#   Tree('NP', [('stephen', 'NN')]),
#   Tree('NP', [('a', 'DT'), ('movie', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('undeniable', 'JJ'), ('ending.the', 'NN')]),
#   Tree('NP', [('script', 'NN')]),
#   Tree('NP', [('the', 'DT'), ('acting', 'NN')]),
#   Tree('NP', [('on.the', 'JJ'), ('storyline', 'NN')]),
#   Tree('NP', [('i', 'NN')]),
#   Tree('NP', [('anything', 'NN')]),
#   Tree('NP', [('anyone', 'NN')]),
#   Tree('NP', [('it.if', 'NN')]),
#   Tree('NP', [('this', 'DT'), ('title', 'NN')])]]
